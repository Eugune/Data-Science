# %% [markdown]
# 3. Change the loss function. An alternative loss for regressions is the Huber loss.
#
# ***The Huber loss is more appropriate than the L2-norm*** when we have outliers, as it is less sensitive to them (in our example we don't have outliers, but you will surely stumble upon a dataset with outliers in the future). The L2-norm loss puts all differences *to the square*, ***so outliers have a lot of influence on the outcome.*** The proper syntax of the Huber loss is 'huber_loss'

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
observations = 1000
xs = np.random.uniform(low=-10, high=10, size=(observations,1))
zs = np.random.uniform(-10, 10, (observations,1))

generated_inputs = np.column_stack((xs,zs))
noise = np.random.uniform(-1, 1, (observations,1))

generated_targets = 2*xs - 3*zs + 5 + noise

np.savez('tf_exp03', inputs=generated_inputs, targets=generated_targets)

# %%
training_data = np.load('tf_exp03.npz')

# %%
input_size = 2
output_size = 1

model = tf.keras.Sequential([

                            tf.keras.layers.Dense(output_size,

                                                 kernel_initializer=tf.random_uniform_initializer(minval=-0.1, maxval=0.1),
                                                 bias_initializer=tf.random_uniform_initializer(minval=-0.1, maxval=0.1)
                                                 )
                            ])


custom_optimizer = tf.keras.optimizers.SGD(learning_rate=0.00001)

model.compile(optimizer=custom_optimizer, loss='huber_loss')

model.fit(training_data['inputs'], training_data['targets'], epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 32/32 - 0s - loss: 17.4200 - 393ms/epoch - 12ms/step
# Epoch 2/100
# 32/32 - 0s - loss: 17.4123 - 46ms/epoch - 1ms/step
# Epoch 3/100
# 32/32 - 0s - loss: 17.4048 - 48ms/epoch - 1ms/step
# Epoch 4/100
# 32/32 - 0s - loss: 17.3972 - 52ms/epoch - 2ms/step
# Epoch 5/100
# 32/32 - 0s - loss: 17.3895 - 47ms/epoch - 1ms/step
# Epoch 6/100
# 32/32 - 0s - loss: 17.3820 - 49ms/epoch - 2ms/step
# Epoch 7/100
# 32/32 - 0s - loss: 17.3744 - 46ms/epoch - 1ms/step
# Epoch 8/100
# 32/32 - 0s - loss: 17.3668 - 52ms/epoch - 2ms/step
# Epoch 9/100
# 32/32 - 0s - loss: 17.3593 - 61ms/epoch - 2ms/step
# Epoch 10/100
# 32/32 - 0s - loss: 17.3516 - 49ms/epoch - 2ms/step
# Epoch 11/100
# 32/32 - 0s - loss: 17.3441 - 49ms/epoch - 2ms/step
# Epoch 12/100
# 32/32 - 0s - loss: 17.3364 - 57ms/epoch - 2ms/step
# Epoch 13/100
# 32/32 - 0s - loss: 17.3289 - 48ms/epoch - 2ms/step
# Epoch 14/100
# 32/32 - 0s - loss: 17.3213 - 45ms/epoch - 1ms/step
# Epoch 15/100
# 32/32 - 0s - loss: 17.3138 - 46ms/epoch - 1ms/step
# Epoch 16/100
# 32/32 - 0s - loss: 17.3062 - 45ms/epoch - 1ms/step
# Epoch 17/100
# 32/32 - 0s - loss: 17.2987 - 47ms/epoch - 1ms/step
# Epoch 18/100
# 32/32 - 0s - loss: 17.2911 - 46ms/epoch - 1ms/step
# Epoch 19/100
# 32/32 - 0s - loss: 17.2835 - 43ms/epoch - 1ms/step
# Epoch 20/100
# 32/32 - 0s - loss: 17.2759 - 44ms/epoch - 1ms/step
# Epoch 21/100
# 32/32 - 0s - loss: 17.2683 - 56ms/epoch - 2ms/step
# Epoch 22/100
# 32/32 - 0s - loss: 17.2607 - 48ms/epoch - 1ms/step
# Epoch 23/100
# 32/32 - 0s - loss: 17.2532 - 50ms/epoch - 2ms/step
# Epoch 24/100
# 32/32 - 0s - loss: 17.2455 - 43ms/epoch - 1ms/step
# Epoch 25/100
# 32/32 - 0s - loss: 17.2379 - 41ms/epoch - 1ms/step
# Epoch 26/100
# 32/32 - 0s - loss: 17.2303 - 47ms/epoch - 1ms/step
# Epoch 27/100
# 32/32 - 0s - loss: 17.2227 - 45ms/epoch - 1ms/step
# Epoch 28/100
# 32/32 - 0s - loss: 17.2151 - 46ms/epoch - 1ms/step
# Epoch 29/100
# 32/32 - 0s - loss: 17.2076 - 45ms/epoch - 1ms/step
# Epoch 30/100
# 32/32 - 0s - loss: 17.2000 - 50ms/epoch - 2ms/step
# Epoch 31/100
# 32/32 - 0s - loss: 17.1925 - 52ms/epoch - 2ms/step
# Epoch 32/100
# 32/32 - 0s - loss: 17.1849 - 58ms/epoch - 2ms/step
# Epoch 33/100
# 32/32 - 0s - loss: 17.1773 - 50ms/epoch - 2ms/step
# Epoch 34/100
# 32/32 - 0s - loss: 17.1697 - 46ms/epoch - 1ms/step
# Epoch 35/100
# 32/32 - 0s - loss: 17.1622 - 48ms/epoch - 1ms/step
# Epoch 36/100
# 32/32 - 0s - loss: 17.1546 - 43ms/epoch - 1ms/step
# Epoch 37/100
# 32/32 - 0s - loss: 17.1471 - 44ms/epoch - 1ms/step
# Epoch 38/100
# 32/32 - 0s - loss: 17.1394 - 50ms/epoch - 2ms/step
# Epoch 39/100
# 32/32 - 0s - loss: 17.1319 - 47ms/epoch - 1ms/step
# Epoch 40/100
# 32/32 - 0s - loss: 17.1243 - 42ms/epoch - 1ms/step
# Epoch 41/100
# 32/32 - 0s - loss: 17.1167 - 49ms/epoch - 2ms/step
# Epoch 42/100
# 32/32 - 0s - loss: 17.1091 - 45ms/epoch - 1ms/step
# Epoch 43/100
# 32/32 - 0s - loss: 17.1016 - 64ms/epoch - 2ms/step
# Epoch 44/100
# 32/32 - 0s - loss: 17.0940 - 46ms/epoch - 1ms/step
# Epoch 45/100
# 32/32 - 0s - loss: 17.0865 - 43ms/epoch - 1ms/step
# Epoch 46/100
# 32/32 - 0s - loss: 17.0789 - 47ms/epoch - 1ms/step
# Epoch 47/100
# 32/32 - 0s - loss: 17.0713 - 50ms/epoch - 2ms/step
# Epoch 48/100
# 32/32 - 0s - loss: 17.0637 - 42ms/epoch - 1ms/step
# Epoch 49/100
# 32/32 - 0s - loss: 17.0562 - 56ms/epoch - 2ms/step
# Epoch 50/100
# 32/32 - 0s - loss: 17.0486 - 46ms/epoch - 1ms/step
# Epoch 51/100
# 32/32 - 0s - loss: 17.0410 - 60ms/epoch - 2ms/step
# Epoch 52/100
# 32/32 - 0s - loss: 17.0335 - 51ms/epoch - 2ms/step
# Epoch 53/100
# 32/32 - 0s - loss: 17.0258 - 53ms/epoch - 2ms/step
# Epoch 54/100
# 32/32 - 0s - loss: 17.0183 - 50ms/epoch - 2ms/step
# Epoch 55/100
# 32/32 - 0s - loss: 17.0106 - 47ms/epoch - 1ms/step
# Epoch 56/100
# 32/32 - 0s - loss: 17.0031 - 47ms/epoch - 1ms/step
# Epoch 57/100
# 32/32 - 0s - loss: 16.9955 - 44ms/epoch - 1ms/step
# Epoch 58/100
# 32/32 - 0s - loss: 16.9880 - 45ms/epoch - 1ms/step
# Epoch 59/100
# 32/32 - 0s - loss: 16.9804 - 48ms/epoch - 2ms/step
# Epoch 60/100
# 32/32 - 0s - loss: 16.9728 - 47ms/epoch - 1ms/step
# Epoch 61/100
# 32/32 - 0s - loss: 16.9654 - 47ms/epoch - 1ms/step
# Epoch 62/100
# 32/32 - 0s - loss: 16.9578 - 49ms/epoch - 2ms/step
# Epoch 63/100
# 32/32 - 0s - loss: 16.9503 - 45ms/epoch - 1ms/step
# Epoch 64/100
# 32/32 - 0s - loss: 16.9427 - 46ms/epoch - 1ms/step
# Epoch 65/100
# 32/32 - 0s - loss: 16.9351 - 55ms/epoch - 2ms/step
# Epoch 66/100
# 32/32 - 0s - loss: 16.9276 - 46ms/epoch - 1ms/step
# Epoch 67/100
# 32/32 - 0s - loss: 16.9200 - 45ms/epoch - 1ms/step
# Epoch 68/100
# 32/32 - 0s - loss: 16.9124 - 47ms/epoch - 1ms/step
# Epoch 69/100
# 32/32 - 0s - loss: 16.9049 - 50ms/epoch - 2ms/step
# Epoch 70/100
# 32/32 - 0s - loss: 16.8973 - 53ms/epoch - 2ms/step
# Epoch 71/100
# 32/32 - 0s - loss: 16.8898 - 56ms/epoch - 2ms/step
# Epoch 72/100
# 32/32 - 0s - loss: 16.8823 - 47ms/epoch - 1ms/step
# Epoch 73/100
# 32/32 - 0s - loss: 16.8748 - 47ms/epoch - 1ms/step
# Epoch 74/100
# 32/32 - 0s - loss: 16.8673 - 43ms/epoch - 1ms/step
# Epoch 75/100
# 32/32 - 0s - loss: 16.8597 - 43ms/epoch - 1ms/step
# Epoch 76/100
# 32/32 - 0s - loss: 16.8521 - 49ms/epoch - 2ms/step
# Epoch 77/100
# 32/32 - 0s - loss: 16.8446 - 45ms/epoch - 1ms/step
# Epoch 78/100
# 32/32 - 0s - loss: 16.8371 - 59ms/epoch - 2ms/step
# Epoch 79/100
# 32/32 - 0s - loss: 16.8295 - 49ms/epoch - 2ms/step
# Epoch 80/100
# 32/32 - 0s - loss: 16.8220 - 44ms/epoch - 1ms/step
# Epoch 81/100
# 32/32 - 0s - loss: 16.8144 - 48ms/epoch - 2ms/step
# Epoch 82/100
# 32/32 - 0s - loss: 16.8068 - 45ms/epoch - 1ms/step
# Epoch 83/100
# 32/32 - 0s - loss: 16.7993 - 45ms/epoch - 1ms/step
# Epoch 84/100
# 32/32 - 0s - loss: 16.7916 - 51ms/epoch - 2ms/step
# Epoch 85/100
# 32/32 - 0s - loss: 16.7841 - 43ms/epoch - 1ms/step
# Epoch 86/100
# 32/32 - 0s - loss: 16.7766 - 55ms/epoch - 2ms/step
# Epoch 87/100
# 32/32 - 0s - loss: 16.7690 - 45ms/epoch - 1ms/step
# Epoch 88/100
# 32/32 - 0s - loss: 16.7614 - 44ms/epoch - 1ms/step
# Epoch 89/100
# 32/32 - 0s - loss: 16.7537 - 52ms/epoch - 2ms/step
# Epoch 90/100
# 32/32 - 0s - loss: 16.7462 - 49ms/epoch - 2ms/step
# Epoch 91/100
# 32/32 - 0s - loss: 16.7387 - 56ms/epoch - 2ms/step
# Epoch 92/100
# 32/32 - 0s - loss: 16.7310 - 46ms/epoch - 1ms/step
# Epoch 93/100
# 32/32 - 0s - loss: 16.7234 - 44ms/epoch - 1ms/step
# Epoch 94/100
# 32/32 - 0s - loss: 16.7159 - 50ms/epoch - 2ms/step
# Epoch 95/100
# 32/32 - 0s - loss: 16.7084 - 47ms/epoch - 1ms/step
# Epoch 96/100
# 32/32 - 0s - loss: 16.7008 - 45ms/epoch - 1ms/step
# Epoch 97/100
# 32/32 - 0s - loss: 16.6933 - 52ms/epoch - 2ms/step
# Epoch 98/100
# 32/32 - 0s - loss: 16.6858 - 45ms/epoch - 1ms/step
# Epoch 99/100
# 32/32 - 0s - loss: 16.6783 - 45ms/epoch - 1ms/step
# Epoch 100/100
# 32/32 - 0s - loss: 16.6708 - 48ms/epoch - 2ms/step

# %% [markdown]
# takeaways:
# 1. Any function that has the property to be lower for better results and higher for worse results can be a loss function.
# This includes the Huber loss.
# 2. Almost everything seems identical.
# 3. The values of the loss are generally lower (because of the Huber loss formula, and the convexity of the two functions).
# 4. For our problem, both the mean squared loss and the Huber loss work equally well.
# ***5. Generally, the Huber loss is used when we have a lot of outliers.***
